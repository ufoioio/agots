# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from agots.generators.behavior_generators import sine_generator
from agots.multivariate_generators.multivariate_data_generator import MultivariateDataGenerator

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 4
K = 2
behavior_config = {'amplitude': 0.3}

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K, behavior=sine_generator, behavior_config=behavior_config)
a = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in a.columns:
    plt.plot(a[col], label=col)
plt.legend()
plt.show()

a.corr()
# Out:
#           x0        x1        x2        x3
# x0  1.000000  0.993299 -0.651881 -0.040794
# x1  0.993299  1.000000 -0.649391 -0.041754
# x2 -0.651881 -0.649391  1.000000  0.394561
# x3 -0.040794 -0.041754  0.394561  1.000000
